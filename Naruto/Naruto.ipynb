# %% [markdown]
# <a align="center">
#     <img src="Naruto1.jpg" width="1550">
# </a>

# %% [markdown]
# <font color='green' size= 6 ><b>Install the following library if not already installed</b></font>

# %% [markdown]
# ##### Pandas: %pip install pandas
#
# ##### Python Dotenv: %pip install python-dotenv
#
# ##### Requests: %pip install requests
#
# ##### Beautiful soup: %pip install bs4
#
# ##### MySQL Connector: %pip install mysql-connector-python
#
# ##### Selenium: %pip install selenium

# %% [markdown]
# <font color='green' size= 6 ><b>Import Library necessary for the Project and define the variables</b></font>

# %%
# importing os ans sys modules
import os
import sys

# Navigate to project directory to import modules

sys.path.insert(0, os.path.dirname(os.getcwd()))

# Importing function create from Manga_function.py
from Functions.Manga_function import write_to_file, create_soup, extract_date, extract_episode, extract_link, extract_title 

# MySQL connector
import mysql.connector

# Pandas
import pandas as pd

# importing os module for environment variables
import os

# importing necessary functions from dotenv library
from dotenv import load_dotenv

# loading variables from .env file
load_dotenv()
# Out:
# True

# %%
# Define the variables

host = os.getenv("MYSQL_HOSTNAME")
user = os.getenv("MYSQL_USERNAME")
password = os.getenv("MYSQL_PASSWORD")
database = "manga"
table_name = "Naruto"
manga_name = "Naruto"
csv_file = "C:/Users/yacbo/Documents/Data_Engineer/Training/Manga_Project/Naruto/Naruto.csv"
log_file = "C:/Users/yacbo/Documents/Data_Engineer/Training/Manga_Project/Naruto/Naruto.txt"
url = os.getenv("URL")
number_tot_ep = 220

# %% [markdown]
# <font color='green' size= 6 ><b>Run "Manga_init.ipynb"</b></font>

# %%
# %run C:\Users\yacbo\Documents\Data_Engineer\Training\Manga_Project\Manga_init.ipynb

# %%
if number_ep_to_extract == 0 :
    write_to_file(log_file, f"Program stopped because there is no data to extract")
    raise SystemExit("System stop because there is no episode to extract")
else:
    # Batch extracting of 40 episodes
    while number_ep_to_extract > 0:
        if number_ep_to_extract > 40:
            batch_ep_to_extract = 40
        else:
            batch_ep_to_extract = number_ep_to_extract

        write_to_file(log_file, f"Extracting {batch_ep_to_extract} episode(s)")

        # run code on "Naruto_ETL" Notebook
        # %run C:\Users\yacbo\Documents\Data_Engineer\Training\Manga_Project\Naruto\Naruto_ETL.ipynb

        # Extract number of episode in database
        try:
                # Execute a query
            cursor.execute(f"SELECT COUNT(*) FROM {table_name}")
            number_ep_database = cursor.fetchall()
            number_ep_database = int(number_ep_database[0][0])
            write_to_file(log_file, f"There is(are) {number_ep_database} episode(s) already in {table_name} table")

        except mysql.connector.Error as err:
            print(f"Error: {err}")

        # Calcul number of episode to extract
        number_ep_to_extract = number_tot_ep - number_ep_database
        write_to_file(log_file, f"There is(are) {number_ep_to_extract} episode(s) to extract")

# Close the database cursor and connection
if cursor:
    cursor.close()
if cnx:
    cnx.close()
